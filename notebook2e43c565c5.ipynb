# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

ds=pd.read_csv("/kaggle/input/covid19turkey/Covid19-Turkey.csv")
ds.head()

#ds1 = ds["Total Cases"]
#ds1.plot()
# Out:
#         Date  Daily Cases  Total Cases  Total Deaths  Total Recovered  \
# 0  3/11/2020            1            1             0                0
# 1  3/12/2020            0            1             0                0
# 2  3/13/2020            4            5             0                0
# 3  3/14/2020            1            6             0                0
# 4  3/15/2020           12           18             0                0
#
#    Active Cases  Daily Test Cases Total Intensive Care  Intubated Cases  \
# 0             1               NaN                  NaN              NaN
# 1             1               NaN                  NaN              NaN
# 2             5               NaN                  NaN              NaN
# 3             6               NaN                  NaN              NaN
# 4            18               NaN                  NaN              NaN
#
#    Case incrase rate %  Daily(Cases/Test) %  (Recovered / Active Cases) %  \
# ...

# %%
ds2 = ds["Total Deaths"]
ds2.plot()
# Out:
# <AxesSubplot:>

# %%
#aynı grafikte iki veriyi görmek istersek
ds1 = ds["Total Cases"]
ds2 = ds["Total Deaths"]
ds2.plot()
ds1.plot()
# Out:
# <AxesSubplot:>

# %%
ds.describe().T
# Out:
#                                count           mean           std  \
# Daily Cases                    147.0    1601.414966   1160.178186
# Total Cases                    147.0  134630.687075  76523.667125
# Total Deaths                   147.0    3481.122449   1996.543307
# Total Recovered                147.0  102486.931973  78371.053601
# Active Cases                   147.0   28662.632653  21354.755705
# Daily Test Cases               139.0   35645.978417  13076.779798
# Intubated Cases                131.0     541.213740    257.241551
# Case incrase rate %            147.0      12.297959     41.816395
# Daily(Cases/Test) %            139.0       6.079137      5.196763
# (Recovered / Active Cases) %   147.0     550.459252    615.699411
# (Death / Active Cases) %       147.0      16.886531     15.855374
# (Active Cases / Population) %  147.0       0.034066      0.025380
#
#                                        min           25%            50%  \
# ...

# %%
ds.corr()
# Out:
#                                Daily Cases  Total Cases  Total Deaths  \
# Daily Cases                       1.000000    -0.285289     -0.316624
# Total Cases                      -0.285289     1.000000      0.995240
# Total Deaths                     -0.316624     0.995240      1.000000
# Total Recovered                  -0.465823     0.962155      0.954829
# Active Cases                      0.716835    -0.040669     -0.031284
# Daily Test Cases                 -0.064919     0.812970      0.796295
# Intubated Cases                   0.893045    -0.662544     -0.709496
# Case incrase rate %              -0.210672    -0.467354     -0.467209
# Daily(Cases/Test) %               0.628230    -0.886629     -0.907840
# (Recovered / Active Cases) %     -0.395555     0.817415      0.774022
# (Death / Active Cases) %         -0.396661     0.847055      0.807750
# (Active Cases / Population) %     0.716835    -0.040669     -0.031284
#
# ...

# %%
import seaborn as sns
sns.heatmap(ds.corr())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="Total Cases", y="Total Deaths", data=ds, color="purple")
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='Total Deaths'>

# %%
#sayısal değişkenlerin dağılımı için histogram çizmek istersek
ds.hist(figsize=(15,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=ds.drop(["(Recovered / Active Cases) %"], axis=1) #bağımsız
y = ds["(Recovered / Active Cases) %"] #bağımlı

# %%
x.head(50) #bağımsız değişkenlerimizi çalıştırmak için
# Out:
#          Date  Daily Cases  Total Cases  Total Deaths  Total Recovered  \
# 0   3/11/2020            1            1             0                0
# 1   3/12/2020            0            1             0                0
# 2   3/13/2020            4            5             0                0
# 3   3/14/2020            1            6             0                0
# 4   3/15/2020           12           18             0                0
# 5   3/16/2020           29           47             0                0
# 6   3/17/2020           51           98             1                0
# 7   3/18/2020           93          191             3                0
# 8   3/19/2020          168          359             4                0
# 9   3/20/2020          311          670             9                0
# 10  3/21/2020          277          947            21                0
# 11  3/22/2020          289         1236            30                0
# ...

# %%
y
# Out:
# 0         0.00
# 1         0.00
# 2         0.00
# 3         0.00
# 4         0.00
#         ...
# 142    1929.10
# 143    1938.62
# 144    1949.00
# 145    1962.80
# 146    1959.21
# Name: (Recovered / Active Cases) %, Length: 147, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x,
                                                   y,
                                                   test_size=0.25,
                                                   random_state=0)

# %%
x_train.head()
# Out:
#           Date  Daily Cases  Total Cases  Total Deaths  Total Recovered  \
# 10   3/21/2020          277          947            21                0
# 132  7/21/2020          928       221974          5526           204011
# 107  6/26/2020         1396       194985          5065           167198
# 59    5/9/2020         1546       137115          3739            89480
# 110  6/29/2020         1374       199087          5115           171809
#
#      Active Cases  Daily Test Cases Total Intensive Care  Intubated Cases  \
# 10            926            2953.0                  NaN              NaN
# 132         12437           42846.0                 1246            379.0
# 107         22722           51198.0                  963            382.0
# 59          43896           35605.0                 1168            628.0
# 110         22163           51014.0                 1018            375.0
#
#      Case incrase rate %  Daily(Cases/Test) %  (Death / Active Cases) %  \
# ...

# %%
x_test.head()
# Out:
#           Date  Daily Cases  Total Cases  Total Deaths  Total Recovered  \
# 7    3/18/2020           93          191             3                0
# 24    4/4/2020         3013        23934           501              786
# 27    4/7/2020         3892        34109           725             1582
# 120   7/9/2020         1024       210436          5300           190390
# 143   8/1/2020          996       232343          5710           215516
#
#      Active Cases  Daily Test Cases Total Intensive Care  Intubated Cases  \
# 7             188               NaN                  NaN              NaN
# 24          22647           19664.0                 1311            909.0
# 27          31802           20023.0                 1474            987.0
# 120         14746           50103.0                 1179            399.0
# 143         11117           44846.0                0.087            586.0
#
#      Case incrase rate %  Daily(Cases/Test) %  (Death / Active Cases) %  \
# ...

# %%
Y_test.head()
# Out:
# 7         0.00
# 24        3.48
# 27        4.98
# 120    1291.13
# 143    1938.62
# Name: (Recovered / Active Cases) %, dtype: float64

# %%
Y_train.head()
# Out:
# 10        0.00
# 132    1640.36
# 107     735.85
# 59      203.85
# 110     775.21
# Name: (Recovered / Active Cases) %, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
